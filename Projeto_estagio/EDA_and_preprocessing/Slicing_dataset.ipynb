# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('df_eng.csv', sep=',')

# %%
df.head()
# Out:
#     data_hora  Temp. Ins. (C)  Temp. Max. (C)  Temp. Min. (C)  Umi. Ins. (%)  \
# 0  2023-01-29       22.969444       23.934722       21.926389      71.111111
# 1  2023-02-05       24.509524       25.198810       23.277381      62.500000
# 2  2023-02-12       25.157143       25.711905       24.029762      58.785714
# 3  2023-02-19       25.451190       26.028571       24.259524      58.630952
# 4  2023-02-26       24.008333       24.713095       23.009524      66.119048
#
#    Umi. Max. (%)  Umi. Min. (%)  Pto Orvalho Ins. (C)  Pto Orvalho Max. (C)  \
# 0      76.722222      66.416667             17.176389             18.104167
# 1      68.726190      59.011905             16.428571             17.429762
# 2      64.428571      56.071429             16.003571             16.991667
# 3      64.285714      55.392857             16.033333             16.938095
# 4      71.095238      62.321429             16.939286             17.777381
#
# ...

# %%
df.tail()
# Out:
#       data_hora  Temp. Ins. (C)  Temp. Max. (C)  Temp. Min. (C)  \
# 100  2024-12-29       23.147619       23.930952       22.148810
# 101  2025-01-05       24.022619       24.807143       23.038095
# 102  2025-01-12       23.044048       23.679762       22.152381
# 103  2025-01-19       22.309524       23.066667       21.395238
# 104  2025-01-26       25.075833       25.806667       23.856667
#
#      Umi. Ins. (%)  Umi. Max. (%)  Umi. Min. (%)  Pto Orvalho Ins. (C)  \
# 100      74.892857      80.250000      70.416667             18.175000
# 101      70.154762      75.547619      66.119048             17.866667
# 102      77.738095      82.369048      74.619048             18.675000
# 103      80.559524      85.464286      77.023810             18.472619
# 104      65.066667      71.275000      60.933333             17.584167
#
#      Pto Orvalho Max. (C)  Pto Orvalho Min. (C)  Pressao Ins. (hPa)  \
# 100             18.915476             17.403571          885.614286
# ...

# %%
# Remover as últimas 4 linhas do DataFrame
new_data = df.iloc[:-4]

# Verificar as primeiras linhas para garantir que as linhas foram removidas
print(new_data.tail())
# Out:
#       data_hora  Temp. Ins. (C)  Temp. Max. (C)  Temp. Min. (C)  \
# 96   2024-12-01       24.511905       25.221429       23.491667
# 97   2024-12-08       25.701786       26.452976       24.534524
# 98   2024-12-15       24.872619       25.696429       23.834524
# 99   2024-12-22       23.782143       24.738095       22.772619
# 100  2024-12-29       23.147619       23.930952       22.148810
#
#      Umi. Ins. (%)  Umi. Max. (%)  Umi. Min. (%)  Pto Orvalho Ins. (C)  \
# 96       68.226190      73.702381      64.333333             17.965476
# 97       57.785714      64.041667      54.047619             15.884524
# 98       65.976190      71.821429      61.428571             17.617857
# 99       71.535714      77.202381      67.119048             17.952381
# 100      74.892857      80.250000      70.416667             18.175000
#
#      Pto Orvalho Max. (C)  Pto Orvalho Min. (C)  Pressao Ins. (hPa)  \
# 96              18.735714             17.202381          886.413095
# ...

# %%
new_data.tail()
# Out:
#       data_hora  Temp. Ins. (C)  Temp. Max. (C)  Temp. Min. (C)  \
# 96   2024-12-01       24.511905       25.221429       23.491667
# 97   2024-12-08       25.701786       26.452976       24.534524
# 98   2024-12-15       24.872619       25.696429       23.834524
# 99   2024-12-22       23.782143       24.738095       22.772619
# 100  2024-12-29       23.147619       23.930952       22.148810
#
#      Umi. Ins. (%)  Umi. Max. (%)  Umi. Min. (%)  Pto Orvalho Ins. (C)  \
# 96       68.226190      73.702381      64.333333             17.965476
# 97       57.785714      64.041667      54.047619             15.884524
# 98       65.976190      71.821429      61.428571             17.617857
# 99       71.535714      77.202381      67.119048             17.952381
# 100      74.892857      80.250000      70.416667             18.175000
#
#      Pto Orvalho Max. (C)  Pto Orvalho Min. (C)  Pressao Ins. (hPa)  \
# 96              18.735714             17.202381          886.413095
# ...

# %%
new_data.shape
# Out:
# (101, 20)

# %%
new_data.to_csv('df_eng_2.csv',index=True)

# %%
df2 = pd.read_csv('df_eng.csv', sep=',')

# %%
df2.tail()
# Out:
#       data_hora  Temp. Ins. (C)  Temp. Max. (C)  Temp. Min. (C)  \
# 100  2024-12-29       23.147619       23.930952       22.148810
# 101  2025-01-05       24.022619       24.807143       23.038095
# 102  2025-01-12       23.044048       23.679762       22.152381
# 103  2025-01-19       22.309524       23.066667       21.395238
# 104  2025-01-26       25.075833       25.806667       23.856667
#
#      Umi. Ins. (%)  Umi. Max. (%)  Umi. Min. (%)  Pto Orvalho Ins. (C)  \
# 100      74.892857      80.250000      70.416667             18.175000
# 101      70.154762      75.547619      66.119048             17.866667
# 102      77.738095      82.369048      74.619048             18.675000
# 103      80.559524      85.464286      77.023810             18.472619
# 104      65.066667      71.275000      60.933333             17.584167
#
#      Pto Orvalho Max. (C)  Pto Orvalho Min. (C)  Pressao Ins. (hPa)  \
# 100             18.915476             17.403571          885.614286
# ...

# %%
ultimo_dataset = df2.tail(4)

# %%
ultimo_dataset.head()
# Out:
#       data_hora  Temp. Ins. (C)  Temp. Max. (C)  Temp. Min. (C)  \
# 101  2025-01-05       24.022619       24.807143       23.038095
# 102  2025-01-12       23.044048       23.679762       22.152381
# 103  2025-01-19       22.309524       23.066667       21.395238
# 104  2025-01-26       25.075833       25.806667       23.856667
#
#      Umi. Ins. (%)  Umi. Max. (%)  Umi. Min. (%)  Pto Orvalho Ins. (C)  \
# 101      70.154762      75.547619      66.119048             17.866667
# 102      77.738095      82.369048      74.619048             18.675000
# 103      80.559524      85.464286      77.023810             18.472619
# 104      65.066667      71.275000      60.933333             17.584167
#
#      Pto Orvalho Max. (C)  Pto Orvalho Min. (C)  Pressao Ins. (hPa)  \
# 101             18.708333             17.166667          885.796429
# 102             19.385714             18.064286          884.198810
# 103             19.261905             17.889286          884.904762
# ...

# %%
ultimo_dataset.to_csv('fazerPrevisoes.csv',index=True)
