# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('df_eng.csv',parse_dates=True,sep=',')

# %%
df.head()
# Out:
#     data_hora  Temp. Ins. (C)  Temp. Max. (C)  Temp. Min. (C)  Umi. Ins. (%)  \
# 0  2023-01-29       22.969444       23.934722       21.926389      71.111111
# 1  2023-02-05       24.509524       25.198810       23.277381      62.500000
# 2  2023-02-12       25.157143       25.711905       24.029762      58.785714
# 3  2023-02-19       25.451190       26.028571       24.259524      58.630952
# 4  2023-02-26       24.008333       24.713095       23.009524      66.119048
#
#    Umi. Max. (%)  Umi. Min. (%)  Pto Orvalho Ins. (C)  Pto Orvalho Max. (C)  \
# 0      76.722222      66.416667             17.176389             18.104167
# 1      68.726190      59.011905             16.428571             17.429762
# 2      64.428571      56.071429             16.003571             16.991667
# 3      64.285714      55.392857             16.033333             16.938095
# 4      71.095238      62.321429             16.939286             17.777381
#
# ...

# %%
df.isnull().sum()
# Out:
# data_hora               0
# Temp. Ins. (C)          0
# Temp. Max. (C)          0
# Temp. Min. (C)          0
# Umi. Ins. (%)           0
# Umi. Max. (%)           0
# Umi. Min. (%)           0
# Pto Orvalho Ins. (C)    0
# Pto Orvalho Max. (C)    0
# Pto Orvalho Min. (C)    0
# Pressao Ins. (hPa)      0
# Pressao Max. (hPa)      0
# Pressao Min. (hPa)      0
# Vel. Vento (m/s)        0
# Dir. Vento (m/s)        0
# Raj. Vento (m/s)        0
# Radiacao (KJ/m²)        0
# Chuva (mm)              0
# Mes                     0
# Ano                     0
# dtype: int64

# %%
df=df.dropna(axis=0)

# %%
df = df.set_index(df['data_hora'])

# %%
df.index
# Out:
# Index(['2023-01-29', '2023-02-05', '2023-02-12', '2023-02-19', '2023-02-26',
#        '2023-03-05', '2023-03-12', '2023-03-19', '2023-03-26', '2023-04-02',
#        ...
#        '2024-11-24', '2024-12-01', '2024-12-08', '2024-12-15', '2024-12-22',
#        '2024-12-29', '2025-01-05', '2025-01-12', '2025-01-19', '2025-01-26'],
#       dtype='object', name='data_hora', length=105)

# %%
df.index = pd.to_datetime(df.index,format='%Y/%m/%d')

# %%
df.columns
# Out:
# Index(['data_hora', 'Temp. Ins. (C)', 'Temp. Max. (C)', 'Temp. Min. (C)',
#        'Umi. Ins. (%)', 'Umi. Max. (%)', 'Umi. Min. (%)',
#        'Pto Orvalho Ins. (C)', 'Pto Orvalho Max. (C)', 'Pto Orvalho Min. (C)',
#        'Pressao Ins. (hPa)', 'Pressao Max. (hPa)', 'Pressao Min. (hPa)',
#        'Vel. Vento (m/s)', 'Dir. Vento (m/s)', 'Raj. Vento (m/s)',
#        'Radiacao (KJ/m²)', 'Chuva (mm)', 'Mes', 'Ano'],
#       dtype='object')

# %%
df.index
# Out:
# DatetimeIndex(['2023-01-29', '2023-02-05', '2023-02-12', '2023-02-19',
#                '2023-02-26', '2023-03-05', '2023-03-12', '2023-03-19',
#                '2023-03-26', '2023-04-02',
#                ...
#                '2024-11-24', '2024-12-01', '2024-12-08', '2024-12-15',
#                '2024-12-22', '2024-12-29', '2025-01-05', '2025-01-12',
#                '2025-01-19', '2025-01-26'],
#               dtype='datetime64[ns]', name='data_hora', length=105, freq=None)

# %%
df = df.drop(['Pto Orvalho Ins. (C)', 'Pto Orvalho Max. (C)', 'Pto Orvalho Min. (C)','Chuva (mm)','Umi. Max. (%)', 'Pressao Ins. (hPa)',
       'Pressao Max. (hPa)', 'Pressao Min. (hPa)','Raj. Vento (m/s)','Dir. Vento (m/s)'],axis=1)

# %%
df.columns
# Out:
# Index(['data_hora', 'Temp. Ins. (C)', 'Temp. Max. (C)', 'Temp. Min. (C)',
#        'Umi. Ins. (%)', 'Umi. Min. (%)', 'Vel. Vento (m/s)',
#        'Radiacao (KJ/m²)', 'Mes', 'Ano'],
#       dtype='object')

# %%
# Reordenar as colunas do DataFrame
new_order = ['Temp. Ins. (C)', 'Temp. Max. (C)', 'Temp. Min. (C)',
       'Umi. Ins. (%)', 'Umi. Min. (%)', 'Vel. Vento (m/s)',
        'Mes', 'Ano','Radiacao (KJ/m²)']  # Substitua pelos nomes das colunas na ordem desejada
df_reordered = df[new_order]

# Verificar o resultado
print(df_reordered.head())
# Out:
#             Temp. Ins. (C)  Temp. Max. (C)  Temp. Min. (C)  Umi. Ins. (%)  \
# data_hora
# 2023-01-29       22.969444       23.934722       21.926389      71.111111
# 2023-02-05       24.509524       25.198810       23.277381      62.500000
# 2023-02-12       25.157143       25.711905       24.029762      58.785714
# 2023-02-19       25.451190       26.028571       24.259524      58.630952
# 2023-02-26       24.008333       24.713095       23.009524      66.119048
#
#             Umi. Min. (%)  Vel. Vento (m/s)  Mes   Ano  Radiacao (KJ/m²)
# data_hora
# 2023-01-29      66.416667          2.709722    1  2023       1580.177778
# 2023-02-05      59.011905          2.294048    2  2023       1767.392857
# 2023-02-12      56.071429          2.236905    2  2023       1762.996429
# 2023-02-19      55.392857          2.513095    2  2023       1892.951190
# 2023-02-26      62.321429          2.292857    2  2023       1735.534524

# %%
df_reordered
# Out:
#             Temp. Ins. (C)  Temp. Max. (C)  Temp. Min. (C)  Umi. Ins. (%)  \
# data_hora
# 2023-01-29       22.969444       23.934722       21.926389      71.111111
# 2023-02-05       24.509524       25.198810       23.277381      62.500000
# 2023-02-12       25.157143       25.711905       24.029762      58.785714
# 2023-02-19       25.451190       26.028571       24.259524      58.630952
# 2023-02-26       24.008333       24.713095       23.009524      66.119048
# ...                    ...             ...             ...            ...
# 2024-12-29       23.147619       23.930952       22.148810      74.892857
# 2025-01-05       24.022619       24.807143       23.038095      70.154762
# 2025-01-12       23.044048       23.679762       22.152381      77.738095
# 2025-01-19       22.309524       23.066667       21.395238      80.559524
# 2025-01-26       25.075833       25.806667       23.856667      65.066667
#
# ...

# %%
df_final = df_reordered.tail(4)

# %%
df_final.head()
# Out:
#             Temp. Ins. (C)  Temp. Max. (C)  Temp. Min. (C)  Umi. Ins. (%)  \
# data_hora
# 2025-01-05       24.022619       24.807143       23.038095      70.154762
# 2025-01-12       23.044048       23.679762       22.152381      77.738095
# 2025-01-19       22.309524       23.066667       21.395238      80.559524
# 2025-01-26       25.075833       25.806667       23.856667      65.066667
#
#             Umi. Min. (%)  Vel. Vento (m/s)  Mes   Ano  Radiacao (KJ/m²)
# data_hora
# 2025-01-05      66.119048          2.363095    1  2025       1450.613095
# 2025-01-12      74.619048          2.839286    1  2025       1394.551190
# 2025-01-19      77.023810          2.967857    1  2025       1472.630952
# 2025-01-26      60.933333          2.290000    1  2025       2000.155000

# %%
df_final.to_csv('jan_2025_xg.csv',index=True)

# %%
df_fina.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 415 entries, 2025-01-25 to 2025-02-25
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Hora (UTC)            415 non-null    int64
#  1   Temp. Ins. (C)        415 non-null    float64
#  2   Temp. Max. (C)        415 non-null    float64
#  3   Temp. Min. (C)        415 non-null    float64
#  4   Umi. Ins. (%)         415 non-null    float64
#  5   Umi. Max. (%)         415 non-null    float64
#  6   Umi. Min. (%)         415 non-null    float64
#  7   Pto Orvalho Ins. (C)  415 non-null    float64
#  8   Pto Orvalho Max. (C)  415 non-null    float64
#  9   Pto Orvalho Min. (C)  415 non-null    float64
#  10  Pressao Ins. (hPa)    415 non-null    float64
#  11  Pressao Max. (hPa)    415 non-null    float64
#  12  Pressao Min. (hPa)    415 non-null    float64
#  13  Vel. Vento (m/s)      415 non-null    float64
# ...

# %%
df= df.resample('W').mean()

# %%
df.shape
# Out:
# (6, 19)

# %%
df.head()
# Out:
#             Temp. Ins. (C)     Ano
# Data
# 2025-01-26       26.448000  2025.0
# 2025-02-02       23.090217  2025.0
# 2025-02-09       24.740659  2025.0
# 2025-02-16       24.208889  2025.0
# 2025-02-23       26.637363  2025.0

# %%
df.columns = ['exog1','exog2']

# %%
df.head()
# Out:
#                 exog1   exog2
# Data
# 2025-01-26  26.448000  2025.0
# 2025-02-02  23.090217  2025.0
# 2025-02-09  24.740659  2025.0
# 2025-02-16  24.208889  2025.0
# 2025-02-23  26.637363  2025.0

# %%
df.index
# Out:
# DatetimeIndex(['2025-01-26', '2025-02-02', '2025-02-09', '2025-02-16',
#                '2025-02-23', '2025-03-02'],
#               dtype='datetime64[ns]', name='Data', freq='W-SUN')

# %%
df.to_csv('exogenas_xg.csv',index=True)

# %% [markdown]
# <h3>Preparando dados para previsão do XGBoost</h3>

# %%
df1 = pd.read_csv('dadosPrevisao.csv',parse_dates=True,sep=';')

# %%
df1=df1.dropna(axis=0)

# %%
df1 = df1.set_index(df1['Data'])

# %%
df1.head()
# Out:
#                   Data  Hora (UTC) Temp. Ins. (C) Temp. Max. (C)  \
# Data
# 25/01/2025  25/01/2025        1000           21,4           21,4
# 25/01/2025  25/01/2025        1100           23,7           23,9
# 25/01/2025  25/01/2025        1200           25,8           25,8
# 25/01/2025  25/01/2025        1300           26,4           26,6
# 25/01/2025  25/01/2025        1400           26,7           27,3
#
#            Temp. Min. (C) Umi. Ins. (%) Umi. Max. (%) Umi. Min. (%)  \
# Data
# 25/01/2025           17,6          78,0          94,0          78,0
# 25/01/2025           21,4          67,0          78,0          67,0
# 25/01/2025           23,6          61,0          69,0          61,0
# 25/01/2025           25,4          60,0          63,0          57,0
# 25/01/2025           25,6          58,0          66,0          57,0
#
#            Pto Orvalho Ins. (C) Pto Orvalho Max. (C) Pto Orvalho Min. (C)  \
# Data
# ...

# %%
df1.index
# Out:
# Index(['25/01/2025', '25/01/2025', '25/01/2025', '25/01/2025', '25/01/2025',
#        '25/01/2025', '25/01/2025', '25/01/2025', '25/01/2025', '25/01/2025',
#        ...
#        '25/02/2025', '25/02/2025', '25/02/2025', '25/02/2025', '25/02/2025',
#        '25/02/2025', '25/02/2025', '25/02/2025', '25/02/2025', '25/02/2025'],
#       dtype='object', name='Data', length=415)

# %%
df1.index = pd.to_datetime(df1.index,format='%Y/%m/%d')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 df1.index = pd.to_datetime(df1.index,format='%Y/%m/%d')
#
# File ~\AppData\Local\miniconda3\envs\projeto_estagio\lib\site-packages\pandas\core\tools\datetimes.py:1072, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1070     result = _assemble_from_unit_mappings(arg, errors, utc)
#    1071 elif isinstance(arg, Index):
# -> 1072     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1073     if not cache_array.empty:
#    1074         result = _convert_and_box_cache(arg, cache_array, name=arg.name)
#
# File ~\AppData\Local\miniconda3\envs\projeto_estagio\lib\site-packages\pandas\core\tools\datetimes.py:247, in _maybe_cache(arg, format, cache, convert_listlike)
#     245 unique_dates = unique(arg)
# ...
